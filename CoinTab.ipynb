# %%
import pandas as pd
import numpy as np

# %%
order_report = pd.read_excel('Company X - Order Report.xlsx')
pincode_zones = pd.read_excel('Company X - Pincode Zones.xlsx')
sku_master = pd.read_excel('Company X - SKU Master.xlsx')
invoice = pd.read_excel('Courier Company - Invoice.xlsx')
rates = pd.read_excel('Courier Company - Rates.xlsx')

# %%
order_report.head(3)
# Out:
#    ExternOrderNo            SKU  Order Qty
# 0     2001827036  8904223818706        1.0
# 1     2001827036  8904223819093        1.0
# 2     2001827036  8904223819109        1.0

# %%
pincode_zones.head(3)
# Out:
#    Warehouse Pincode  Customer Pincode Zone
# 0             121003            507101    d
# 1             121003            486886    d
# 2             121003            532484    d

# %%
sku_master.head(3)
# Out:
#              SKU  Weight (g)
# 0  8904223815682         210
# 1  8904223815859         165
# 2  8904223815866         113

# %%
invoice.head(3)
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232             1.3             121003
# 1  1091117222194  2001806273             1.0             121003
# 2  1091117222931  2001806408             2.5             121003
#
#    Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)
# 0            507101    d  Forward charges                 135.0
# 1            486886    d  Forward charges                  90.2
# 2            532484    d  Forward charges                 224.6

# %%
rates.head(3)
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
order_master = pd.merge(order_report, sku_master, on='SKU')

# %%
order_master
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)
# 0       2001827036  8904223818706        1.0         127
# 1       2001821995  8904223818706        1.0         127
# 2       2001819252  8904223818706        1.0         127
# 3       2001816996  8904223818706        1.0         127
# 4       2001814580  8904223818706        1.0         127
# ..             ...            ...        ...         ...
# 396     2001806616  8904223819123        1.0         250
# 397     2001806567  8904223815804        1.0         160
# 398     2001806567  8904223818577        1.0         150
# 399     2001806408  8904223819437        2.0         552
# 400     2001806232  8904223818645        6.0         137
#
# [401 rows x 4 columns]

# %%
order_master.isnull().sum()
# Out:
# ExternOrderNo    0
# SKU              0
# Order Qty        0
# Weight (g)       0
# dtype: int64

# %%
order_master_invoice = pd.merge(order_master, invoice, left_on='ExternOrderNo', right_on='Order ID')

# %%
order_master_invoice
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)       AWB Code  \
# 0       2001827036  8904223818706        1.0         127  1091122418320
# 1       2001827036  8904223819093        1.0         150  1091122418320
# 2       2001827036  8904223819109        1.0         100  1091122418320
# 3       2001827036  8904223818430        1.0         165  1091122418320
# 4       2001827036  8904223819277        1.0         350  1091122418320
# ..             ...            ...        ...         ...            ...
# 396     2001806251  8904223819161        1.0         115  1091117222146
# 397     2001806251  8904223819260        1.0         130  1091117222146
# 398     2001806233  8904223819161        1.0         115  1091117222135
# 399     2001806233  8904223819260        1.0         130  1091117222135
# 400     2001807328  8904223818997        1.0         490  1091117324346
#
#        Order ID  Charged Weight  Warehouse Pincode  Customer Pincode Zone  \
# ...

# %%
final_report = pd.merge(order_master_invoice, pincode_zones, on='Customer Pincode')

# %%
pincode_zones[pincode_zones['Zone'] == 'e']
# Out:
#      Warehouse Pincode  Customer Pincode Zone
# 18              121003            673002    e
# 26              121003            783301    e
# 87              121003            173212    e
# 88              121003            174101    e
# 89              121003            173213    e
# 102             121003            175101    e
# 122             121003            173212    e

# %%
final_report
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)       AWB Code  \
# 0       2001827036  8904223818706        1.0         127  1091122418320
# 1       2001827036  8904223819093        1.0         150  1091122418320
# 2       2001827036  8904223819109        1.0         100  1091122418320
# 3       2001827036  8904223818430        1.0         165  1091122418320
# 4       2001827036  8904223819277        1.0         350  1091122418320
# ..             ...            ...        ...         ...            ...
# 562     2001806251  8904223819161        1.0         115  1091117222146
# 563     2001806251  8904223819260        1.0         130  1091117222146
# 564     2001806233  8904223819161        1.0         115  1091117222135
# 565     2001806233  8904223819260        1.0         130  1091117222135
# 566     2001807328  8904223818997        1.0         490  1091117324346
#
#        Order ID  Charged Weight  Warehouse Pincode_x  Customer Pincode Zone_x  \
# ...

# %%
final_report['Weight (g)'].max()
# Out:
# 600

# %%
final_report['weight_slab_X'] = ''

# %%
def weight(value):
    if value <= 50:
        return 'A'
    elif value > 50 and value <= 100:
        return 'B'
    elif value > 100 and value <= 150:
        return 'C'
    elif value > 150 and value <= 200:
        return 'D'
    elif value > 200 and value <= 250:
        return 'E'
    elif value > 250 and value <= 300:
        return 'F'
    elif value > 300 and value <= 350:
        return 'G'
    elif value > 350 and value <= 400:
        return 'H'
    elif value > 400 and value <= 450:
        return 'I'
    elif value > 450 and value <= 500:
        return 'J'
    elif value > 500 and value <= 550:
        return 'K'
    elif value > 550 and value <= 600:
        return 'L'
    else:
        return np.NaN
    
final_report = final_report.assign(weight_slab_X = final_report['Weight (g)'].apply(weight))

# %%
rates.head(3)
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
final_report['weight_slab_X'].value_counts()
# Out:
# 0.50    44
# 0.68    37
# 1.00    36
# 2.10    32
# 0.70    28
# 0.80    26
# 0.20    25
# 0.72    24
# 1.10    22
# 1.86    20
# 0.71    18
# 0.67    15
# 3.00    14
# 1.60    14
# 0.79    12
# 1.15    12
# 0.69    12
# 1.13    11
# 1.50    11
# 0.60    11
# 1.08    10
# 1.30    10
# 1.20     8
# 2.94     8
# 1.70     7
# 0.77     6
# 1.16     6
# 1.28     6
# 0.76     6
# 0.73     6
# 0.15     6
# 2.00     5
# 0.59     5
# 1.64     4
# 2.50     4
# 1.35     4
# 0.61     4
# 1.04     3
# 2.86     3
# 0.74     3
# 0.66     3
# 2.27     3
# 0.30     3
# 0.99     3
# 1.27     2
# 0.86     2
# 0.82     2
# 4.13     2
# 1.63     2
# 2.92     2
# 0.78     2
# 2.47     1
# 1.02     1
# 2.28     1
# Name: Charged Weight, dtype: int64

# %% [markdown]
# ### Weight slab as per Courier Company

# %%
final_report['Weight_slab_courier'] = ''

# %%
def weight_courier(value):
    if value <= 0.5:
        return 'A'
    elif value > 0.5 and value <= 1:
        return 'B'
    elif value > 1 and value <= 1.5:
        return 'C'
    elif value > 1.5 and value <= 2:
        return 'D'
    elif value > 2 and value <= 2.5:
        return 'E'
    elif value > 2.5 and value <= 3:
        return 'F'
    elif value > 3 and value <= 3.5:
        return 'G'
    elif value > 3.5 and value <= 4:
        return 'H'
    elif value > 4 and value <= 4.5:
        return 'I'
    elif value > 4.5 and value <= 5:
        return 'J'
    elif value > 5 and value <= 5.5:
        return 'K'
    elif value > 5.5 and value <= 6:
        return 'L'
    else:
        return np.NaN
    
final_report = final_report.assign(Weight_slab_courier = final_report['Charged Weight'].apply(weight_courier))

# %%
final_report.rename(columns = {'Zone_x':'Zone_courier', 'Zone_y':'Zone_X', 'Warehouse Pincode_x':'Warehouse Pincode_courier', 'Warehouse Pincode_y':'Warehouse Pincode_X'}, inplace = True)

# %%
final_report
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)       AWB Code  \
# 0       2001827036  8904223818706        1.0         127  1091122418320
# 1       2001827036  8904223819093        1.0         150  1091122418320
# 2       2001827036  8904223819109        1.0         100  1091122418320
# 3       2001827036  8904223818430        1.0         165  1091122418320
# 4       2001827036  8904223819277        1.0         350  1091122418320
# ..             ...            ...        ...         ...            ...
# 562     2001806251  8904223819161        1.0         115  1091117222146
# 563     2001806251  8904223819260        1.0         130  1091117222146
# 564     2001806233  8904223819161        1.0         115  1091117222135
# 565     2001806233  8904223819260        1.0         130  1091117222135
# 566     2001807328  8904223818997        1.0         490  1091117324346
#
#        Order ID  Charged Weight  Warehouse Pincode_courier  Customer Pincode  \
# ...

# %%
final_report['Type of Shipment'].value_counts()
# Out:
# Forward charges            517
# Forward and RTO charges     50
# Name: Type of Shipment, dtype: int64

# %%
def charge_as_per_X(ship_type,zone,weight_slab):
    if ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'A':
        return float(33)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'B':
        return float(33+28.3)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'C':
        return float(33+28.3*2)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'D':
        return float(33+28.3*3)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'E':
        return float(33+28.3*4)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'F':
        return float(33+28.3*5)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'G':
        return float(33+28.3*6)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'H':
        return float(33+28.3*7)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'I':
        return float(33+28.3*8)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'J':
        return float(33+28.3*9)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'K':
        return float(33+28.3*10)
    elif ship_type == 'Forward charges' and zone == 'b' and weight_slab == 'L':
        return float(33+28.3*11)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'A':
        return float(45.4)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'B':
        return float(45.4+44.8)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'C':
        return float(45.4+44.8*2)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'D':
        return float(45.4+44.8*3)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'E':
        return float(45.4+44.8*4)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'F':
        return float(45.4+44.8*5)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'G':
        return float(45.4+44.8*6)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'H':
        return float(45.4+44.8*7)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'I':
        return float(45.4+44.8*8)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'J':
        return float(45.4+44.8*9)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'K':
        return float(45.4+44.8*10)
    elif ship_type == 'Forward charges' and zone == 'd' and weight_slab == 'L':
        return float(45.4+44.8*11)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'A':
        return float(56.6)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'B':
        return float(56.6+55.5)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'C':
        return float(56.6+55.5*2)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'D':
        return float(56.6+55.5*3)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'E':
        return float(56.6+55.5*4)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'F':
        return float(56.6+55.5*5)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'G':
        return float(56.6+55.5*6)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'H':
        return float(56.6+55.5*7)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'I':
        return float(56.6+55.5*8)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'J':
        return float(56.6+55.5*9)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'K':
        return float(56.6+55.5*10)
    elif ship_type == 'Forward charges' and zone == 'e' and weight_slab == 'L':
        return float(56.6+55.5*11)
    if ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'A':
        return float(33+20.5)
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'B':
        return float(33+20.5+28.3+28.3)
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'C':
        return float(33+20.5+(28.3*2)+(28.3*2))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'D':
        return float(33+20.5+(28.3*3)+(28.3*3))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'E':
        return float(33+20.5+(28.3*4)+(28.3*4))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'F':
        return float(33+20.5+(28.3*5)+(28.3*5))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'G':
        return float(33+20.5+(28.3*6)+(28.3*6))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'H':
        return float(33+20.5+(28.3*7)+(28.3*7))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'I':
        return float(33+20.5+(28.3*8)+(28.3*8))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'J':
        return float(33+20.5+(28.3*9)+(28.3*9))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'K':
        return float(33+20.5+(28.3*10)+(28.3*10))
    elif ship_type == 'Forward and RTO charges' and zone == 'b' and weight_slab == 'L':
        return float(33+20.5+(28.3*11)+(28.3*11))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'A':
        return float(45.4+41.3)
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'B':
        return float(45.4+41.3+44.8+44.8)
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'C':
        return float(45.4+41.3+(44.8*2)+(44.8*2))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'D':
        return float(45.4+41.3+(44.8*3)+(44.8*3))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'E':
        return float(45.4+41.3+(44.8*4)+(44.8*4))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'F':
        return float(45.4+41.3+(44.8*5)+(44.8*5))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'G':
        return float(45.4+41.3+(44.8*6)+(44.8*6))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'H':
        return float(45.4+41.3+(44.8*7)+(44.8*7))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'I':
        return float(45.4+41.3+(44.8*8)+(44.8*8))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'J':
        return float(45.4+41.3+(44.8*9)+(44.8*9))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'K':
        return float(45.4+41.3+(44.8*10)+(44.8*10))
    elif ship_type == 'Forward and RTO charges' and zone == 'd' and weight_slab == 'L':
        return float(45.4+41.3+(44.8*11)+(44.8*11))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'A':
        return float(56.6+50.7)
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'B':
        return float(56.6+50.7+55.5)
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'C':
        return float(56.6+50.7+(55.5*2)+(55.5*2))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'D':
        return float(56.6+50.7+(55.5*3)+(55.5*3))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'E':
        return float(56.6+50.7+(55.5*4)+(55.5*4))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'F':
        return float(56.6+50.7+(55.5*5)+(55.5*5))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'G':
        return float(56.6+50.7+(55.5*6)+(55.5*6))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'H':
        return float(56.6+50.7+(55.5*7)+(55.5*7))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'I':
        return float(56.6+50.7+(55.5*8)+(55.5*8))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'J':
        return float(56.6+50.7+(55.5*9)+(55.5*9))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'K':
        return float(56.6+50.7+(55.5*10)+(55.5*10))
    elif ship_type == 'Forward and RTO charges' and zone == 'e' and weight_slab == 'L':
        return float(56.6+50.7+(55.5*11)+(55.5*11))
    else:
        return np.NaN

# %%
final_report['Expected_charges'] = ''

# %%
final_report = final_report.assign(Expected_charges = final_report.apply(lambda row: charge_as_per_X(row['Type of Shipment'], row['Zone_X'], row['weight_slab_X']), axis=1))

# %%
final_report['Zone_courier'].value_counts()
# Out:
# d    454
# b    108
# e      5
# Name: Zone_courier, dtype: int64

# %%
rates.head(3)
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
final_report
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)       AWB Code  \
# 0       2001827036  8904223818706        1.0         127  1091122418320
# 1       2001827036  8904223819093        1.0         150  1091122418320
# 2       2001827036  8904223819109        1.0         100  1091122418320
# 3       2001827036  8904223818430        1.0         165  1091122418320
# 4       2001827036  8904223819277        1.0         350  1091122418320
# ..             ...            ...        ...         ...            ...
# 562     2001806251  8904223819161        1.0         115  1091117222146
# 563     2001806251  8904223819260        1.0         130  1091117222146
# 564     2001806233  8904223819161        1.0         115  1091117222135
# 565     2001806233  8904223819260        1.0         130  1091117222135
# 566     2001807328  8904223818997        1.0         490  1091117324346
#
#        Order ID  Charged Weight  Warehouse Pincode_courier  Customer Pincode  \
# ...

# %%
final_report['Difference_between_expected_and_billed_amount'] = ''

# %%
final_report['Difference_between_expected_and_billed_amount'] = final_report['Billing Amount (Rs.)'].sub(final_report['Expected_charges'], axis=0)

# %%
final_report
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)       AWB Code  \
# 0       2001827036  8904223818706        1.0         127  1091122418320
# 1       2001827036  8904223819093        1.0         150  1091122418320
# 2       2001827036  8904223819109        1.0         100  1091122418320
# 3       2001827036  8904223818430        1.0         165  1091122418320
# 4       2001827036  8904223819277        1.0         350  1091122418320
# ..             ...            ...        ...         ...            ...
# 562     2001806251  8904223819161        1.0         115  1091117222146
# 563     2001806251  8904223819260        1.0         130  1091117222146
# 564     2001806233  8904223819161        1.0         115  1091117222135
# 565     2001806233  8904223819260        1.0         130  1091117222135
# 566     2001807328  8904223818997        1.0         490  1091117324346
#
#        Order ID  Charged Weight  Warehouse Pincode_courier  Customer Pincode  \
# ...

# %%
final_report.to_excel('cointab_final_report.xlsx', index = False)
